# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Read Data
#
# Read restaurants and weekly patterns. Join by place id

# %%
data_dir = '../Data'

# %%
rest_path = data_dir + '/Restaurants/core_poi.csv.gz'
restaurants = pd.read_csv(rest_path)

# %%
restaurants.head()
# Out:
#               placekey                   safegraph_place_id  \
# 0  zzy-222@5qk-kqf-btv  sg:004876ea198c40d28ad9e7e5080ece08
# 1  22b-222@63j-gs8-389  sg:014e6d779d6240c8895c06abf85d1b43
# 2  223-224@8fw-38c-c5z  sg:01998dc61eda46f09a0107fa894cb91d
# 3  zzw-222@5pk-nbk-qpv  sg:01b0062b02ea4c5bab337c4a2cf18846
# 4  zzy-225@5wg-jfw-hqz  sg:01ea2d04c6644d0d97324f25cc092307
#
#              parent_safegraph_place_id        location_name  \
# 0                                  NaN               Bash's
# 1  sg:104f486607f8458f9fcac57a442a7069            Pizza Hut
# 2                                  NaN          Pizza Mafia
# 3                                  NaN        House of Wong
# 4                                  NaN  Park One Restaurant
#
#                          safegraph_brand_ids     brands  \
# 0                                        NaN        NaN
# 1  SG_BRAND_1f2a4b730dc533366115ba7f5168b074  Pizza Hut
# 2                                        NaN        NaN
# ...

# %% [markdown]
# ## Exploratory analysis
#
# Plot distributions by:
# - sub_category
# - has a national brand
# - state
#
# Plot changes in travel, aggregated by:
# - state
# - city
# - has a national brand
#
# Plot changes in travel by weekday/weekend

# %% [markdown]
# ## Feature engineering
#
# - is a national brand dummy variable
# - change in weekly visits
#     + (overall for now, consider splitting by weekday/weekend)
#     + Use a baseline of February? Should we try "same time last year"?
# - spatial lag? Helps account for any sort of local business stimuluses.
